# %%
import pandas as pd
import numpy as np

df = pd.read_excel(r'C:\Users\candi\Downloads\coalpublic2013.xls', header=[3])
df
# Out:
#       Year  MSHA ID                       Mine Name       Mine State  \
# 0     2013   103381            Tacoa Highwall Miner          Alabama
# 1     2013   103404                Reid School Mine          Alabama
# 2     2013   100759  North River #1 Underground Min          Alabama
# 3     2013   103246                      Bear Creek          Alabama
# 4     2013   103451                     Knight Mine          Alabama
# ...    ...      ...                             ...              ...
# 1445  2013  1103254                   Fidelity Mine  Refuse Recovery
# 1446  2013  1102636                             Wfi  Refuse Recovery
# 1447  2013  4407233                        Gobco #8  Refuse Recovery
# 1448  2013  1518524               Turkey Pen Refuse  Refuse Recovery
# 1449  2013  1519685           Fedscreek Refuse Pile  Refuse Recovery
#
#      Mine County                         Mine Status    Mine Type  \
# 0           Bibb  Active, men working, not producing      Surface
# ...

# %%
df.get('Union Code')
# Out:
# 0
# 1       UNIT
# 2       UNIT
# 3
# 4
#         ...
# 1445
# 1446
# 1447
# 1448
# 1449
# Name: Union Code, Length: 1450, dtype: object

# %%
df['Mine State']
# Out:
# 0               Alabama
# 1               Alabama
# 2               Alabama
# 3               Alabama
# 4               Alabama
#              ...
# 1445    Refuse Recovery
# 1446    Refuse Recovery
# 1447    Refuse Recovery
# 1448    Refuse Recovery
# 1449    Refuse Recovery
# Name: Mine State, Length: 1450, dtype: object

# %%
df_ = df.astype(dtype={'Year': np.int32, 'Labor Hours': np.float32})
df_
# Out:
#       Year  MSHA ID                       Mine Name       Mine State  \
# 0     2013   103381            Tacoa Highwall Miner          Alabama
# 1     2013   103404                Reid School Mine          Alabama
# 2     2013   100759  North River #1 Underground Min          Alabama
# 3     2013   103246                      Bear Creek          Alabama
# 4     2013   103451                     Knight Mine          Alabama
# ...    ...      ...                             ...              ...
# 1445  2013  1103254                   Fidelity Mine  Refuse Recovery
# 1446  2013  1102636                             Wfi  Refuse Recovery
# 1447  2013  4407233                        Gobco #8  Refuse Recovery
# 1448  2013  1518524               Turkey Pen Refuse  Refuse Recovery
# 1449  2013  1519685           Fedscreek Refuse Pile  Refuse Recovery
#
#      Mine County                         Mine Status    Mine Type  \
# 0           Bibb  Active, men working, not producing      Surface
# ...

# %% [markdown]
# NOT (~)
# AND (&)
# OR (|)
# XOR (^)

# %%
Uni = df[(df['Production (short tons)'] >= 28000) & (df['Average Employees'] == 10 )]
Uni
# Out:
#       Year  MSHA ID                    Mine Name                Mine State  \
# 0     2013   103381         Tacoa Highwall Miner                   Alabama
# 37    2013   103195  Mccollum/Sparks Branch Mine                   Alabama
# 156   2013  1519608                         No 2           Kentucky (East)
# 401   2013  1518978       Buckeye Highwall Miner           Kentucky (East)
# 478   2013  1519604            Beaver Mine No. 1           Kentucky (East)
# 518   2013  1800776                No. 1 Surface                  Maryland
# 590   2013  3401343                 Phoenix No 3                  Oklahoma
# 1025  2013  4407313               Maple Highwall                  Virginia
# 1279  2013  4606089               Minway Surface  West Virginia (Southern)
# 1317  2013  4607355                     Bucy Job  West Virginia (Northern)
#
#      Mine County                         Mine Status Mine Type  \
# 0           Bibb  Active, men working, not producing   Surface
# ...

# %%
Uni2 = df[(df['Mine Type'] == 'Underground') & (df['Average Employees'] == 10 )]
Uni2
# Out:
#       Year  MSHA ID               Mine Name                 Mine State  \
# 440   2013  1518436              Mine No. 1            Kentucky (East)
# 554   2013  3304188  Kensington Prep. Plant                       Ohio
# 874   2013  3606330          Cleaning Plant  Pennsylvania (Bituminous)
# 1226  2013  4607852        Big Creek Washer   West Virginia (Southern)
# 1233  2013  4608955              Mine No. 2   West Virginia (Southern)
# 1316  2013  4606556          River Terminal   West Virginia (Northern)
#
#      Mine County                         Mine Status    Mine Type  \
# 440         Pike               Permanently abandoned  Underground
# 554   Columbiana  Active, men working, not producing  Underground
# 874     Somerset                              Active  Underground
# 1226    Mcdowell                              Active  Underground
# 1233    Mcdowell                              Active  Underground
# 1316  Monongalia                              Active  Underground
#
# ...

# %%
df_sub=df[['MSHA ID', 'Labor Hours']].groupby('MSHA ID').sum()
df_sub
# Out:
#          Labor Hours
# MSHA ID
# 100329        144002
# 100347        215295
# 100515          6240
# 100759        474784
# 100851       1001809
# ...              ...
# 4801353      2811138
# 4801429       161270
# 4801645        35687
# 4801646       661265
# 5000030       286079
#
# [1321 rows x 1 columns]

# %%
df_sub_mean = df[['MSHA ID', 'Labor Hours']].groupby('MSHA ID').mean()
df_sub_mean
# Out:
#          Labor Hours
# MSHA ID
# 100329      144002.0
# 100347      215295.0
# 100515        6240.0
# 100759      474784.0
# 100851     1001809.0
# ...              ...
# 4801353    2811138.0
# 4801429     161270.0
# 4801645      35687.0
# 4801646     661265.0
# 5000030     286079.0
#
# [1321 rows x 1 columns]

# %%
df_sub - df_sub_mean
# Out:
#          Labor Hours
# MSHA ID
# 100329           0.0
# 100347           0.0
# 100515           0.0
# 100759           0.0
# 100851           0.0
# ...              ...
# 4801353          0.0
# 4801429          0.0
# 4801645          0.0
# 4801646          0.0
# 5000030          0.0
#
# [1321 rows x 1 columns]

# %% [markdown]
# https://realpython.com/pandas-dataframe/#applying-arithmetic-operations
