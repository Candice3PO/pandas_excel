# %% [markdown]
# # This is just a test to show Ale how to use Jupyter.
# x = $y^2$

# %%
x = 5
print(x)
# Out:
# 5

# %%
import matplotlib.pyplot as plt 
import numpy as np

x = np.linspace(1,10,10)
plt.plot(x)
plt.show()

# %%
import pandas as pd
import numpy as np

# names=['Year',	'MSHA', 'ID', 'Mine Name',	'Mine State',	'Mine County',	'Mine Status',	'Mine Type',	'Company Type',	'Operation Type',	'Operating Company',	'Operating Company Address',	'Union Code',	'Coal Supply Region',	'Production (short tons)',	'Average Employees',	'Labor Hours']
df = pd.read_excel(r'C:\Users\Alessandra\Dropbox\PC\Downloads\coalpublic2013.xls', header=[2]) #alternatively to header= [2], use skiprows=2

print(df)
print(df.drop([0,1], axis=0, inplace=True))
print(df.dtypes)

cols=[0,1,13,14,15]
intdf=pd.read_excel(r'C:\Users\Alessandra\Dropbox\PC\Downloads\coalpublic2013.xls', header=[2], usecols=cols)
print(intdf)

print('Sum:', df['Production (short tons)'].sum())
print('Mean:', df['Production (short tons)'].mean())
print('Max:', df['Production (short tons)'].max())
print('Min:', df['Production (short tons)'].min())

df.insert(3, "ka2", np.nan)
print(df)

sum_row=df[['Production (short tons)', 'Average Employees', 'Labor Hours']].sum()
df_sum=pd.DataFrame(data=sum_row).T
df_sum=df_sum.reindex(columns=df.columns)
print(df_sum)
# Out:
#       Year  MSHA ID                       Mine Name       Mine State  \
# 0     2013   103381            Tacoa Highwall Miner          Alabama
# 1     2013   103404                Reid School Mine          Alabama
# 2     2013   100759  North River #1 Underground Min          Alabama
# 3     2013   103246                      Bear Creek          Alabama
# 4     2013   103451                     Knight Mine          Alabama
# ...    ...      ...                             ...              ...
# 1445  2013  1103254                   Fidelity Mine  Refuse Recovery
# 1446  2013  1102636                             Wfi  Refuse Recovery
# 1447  2013  4407233                        Gobco #8  Refuse Recovery
# 1448  2013  1518524               Turkey Pen Refuse  Refuse Recovery
# 1449  2013  1519685           Fedscreek Refuse Pile  Refuse Recovery
#
#      Mine County                         Mine Status    Mine Type  \
# 0           Bibb  Active, men working, not producing      Surface
# ...

# %%
df.tail(n=10)
# Out:
#       Year  MSHA ID              Mine Name  ka2       Mine State  \
# 1440  2013  3609405                Phoenix  NaN  Refuse Recovery
# 1441  2013   100515      Mary Lee # 1 Mine  NaN  Refuse Recovery
# 1442  2013  3609337     Marco Gfcc Project  NaN  Refuse Recovery
# 1443  2013  1518401                  No. 1  NaN  Refuse Recovery
# 1444  2013  1519713             # 1 Refuse  NaN  Refuse Recovery
# 1445  2013  1103254          Fidelity Mine  NaN  Refuse Recovery
# 1446  2013  1102636                    Wfi  NaN  Refuse Recovery
# 1447  2013  4407233               Gobco #8  NaN  Refuse Recovery
# 1448  2013  1518524      Turkey Pen Refuse  NaN  Refuse Recovery
# 1449  2013  1519685  Fedscreek Refuse Pile  NaN  Refuse Recovery
#
#        Mine County                         Mine Status Mine Type  \
# 1440    Washington                              Active    Refuse
# 1441        Walker  Active, men working, not producing    Refuse
# ...

# %%
df_sub=df[['MSHA ID', 'Labor Hours']].groupby('MSHA ID').sum()
df_sub
# Out:
#          Labor Hours
# MSHA ID
# 100329        144002
# 100347        215295
# 100515          6240
# 100759        474784
# 100851       1001809
# ...              ...
# 4801353      2811138
# 4801429       161270
# 4801645        35687
# 4801646       661265
# 5000030       286079
#
# [1319 rows x 1 columns]

# %% [markdown]
# #Write a Pandas program to import given excel data (coalpublic2013.xlsx) into a dataframe and find details where 'Labor Hours' > 20000

# %%
df[df["Labor Hours"] > 20000]
# Out:
#       Year  MSHA ID                       Mine Name  ka2       Mine State  \
# 2     2013   100759  North River #1 Underground Min  NaN          Alabama
# 3     2013   103246                      Bear Creek  NaN          Alabama
# 4     2013   103451                     Knight Mine  NaN          Alabama
# 5     2013   103433              Crane Central Mine  NaN          Alabama
# 6     2013   100329                    Concord Mine  NaN          Alabama
# ...    ...      ...                             ...  ...              ...
# 1418  2013  4800677                Jim Bridger Mine  NaN          Wyoming
# 1419  2013  4801180   Black Butte And Leucite Hills  NaN          Wyoming
# 1420  2013  4801646   Bridger Underground Coal Mine  NaN          Wyoming
# 1428  2013  3603561                   Mcclure Strip  NaN  Refuse Recovery
# 1447  2013  4407233                        Gobco #8  NaN  Refuse Recovery
#
#      Mine County                         Mine Status    Mine Type  \
# ...

# %%
df_sub=df[['MSHA ID', 'Labor Hours']].groupby('MSHA ID').sum()
BARPLOT=df_sub.plot(kind='hist')
BARPLOT

# %% [markdown]
# #Write a Pandas program to import given excel data (coalpublic2013.xlsx ) into a dataframe and find details where "Mine Name" starts with "P".

# %%
df["Mine Name"] = df["Mine Name"].astype(str)
print(df["Mine Name"].head())
# Out:
# 2    North River #1 Underground Min
# 3                        Bear Creek
# 4                       Knight Mine
# 5                Crane Central Mine
# 6                      Concord Mine
# Name: Mine Name, dtype: object

# %% [markdown]
# # Metti una maschera booleana cosicche vedi solo quando la condizione è vera: df[funzione]

# %%
PSTARTING= df[df["Mine Name"].map(lambda x: x.startswith('P'))]
PSTARTING
# Out:
#       Year  MSHA ID                      Mine Name  ka2  \
# 13    2013   103332                  Powhatan Mine  NaN
# 18    2013   102976  Piney Woods Preparation Plant  NaN
# 19    2013   102976  Piney Woods Preparation Plant  NaN
# 46    2013   103321                 Poplar Springs  NaN
# 50    2013   301569                       Penny #1  NaN
# ...    ...      ...                            ...  ...
# 1389  2013  4605868     Pinnacle Preparation Plant  NaN
# 1424  2013  4605995         Preparation Plant No 1  NaN
# 1437  2013  3610027                  Paradise Bank  NaN
# 1438  2013  3609304         Park Mine Coal Company  NaN
# 1440  2013  3609405                        Phoenix  NaN
#
#                     Mine State     Mine County              Mine Status  \
# 13                     Alabama       Jefferson                   Active
# 18                     Alabama          Shelby                   Active
# 19                     Alabama          Shelby                   Active
# ...

# %% [markdown]
# Write a Pandas program to import given excel data (coalpublic2013.xls ) into a dataframe and find all records that include two specific MSHA ID

# %%
IDNUMBERS = df[df['MSHA ID'].isin([102976, 103380])]
IDNUMBERS
# Out:
#     Year  MSHA ID                      Mine Name  ka2 Mine State Mine County  \
# 18  2013   102976  Piney Woods Preparation Plant  NaN    Alabama      Shelby
# 19  2013   102976  Piney Woods Preparation Plant  NaN    Alabama      Shelby
# 20  2013   103380                         Calera  NaN    Alabama      Shelby
# 21  2013   103380                         Calera  NaN    Alabama      Shelby
#
#    Mine Status    Mine Type                  Company Type     Operation Type  \
# 18      Active      Surface  Indepedent Producer Operator  Preparation Plant
# 19      Active  Underground  Indepedent Producer Operator  Preparation Plant
# 20      Active      Surface  Indepedent Producer Operator  Preparation Plant
# 21      Active  Underground  Indepedent Producer Operator  Preparation Plant
#
#                  Operating Company                Operating Company Address  \
# 18         Jesse Creek Mining, Llc  1615 Kent Dairy Rd, Alabaster, AL 35007
# ...

# %%
print(df[df['MSHA ID'].isin([102976, 103380])].shape)
# Out:
# (4, 18)

# %% [markdown]
# Find a list of specified customers by name

# %%
type(df["Mine Name"])
# Out:
# pandas.core.series.Series

# %%
with pd.ExcelWriter(r'C:\Users\Alessandra\Dropbox\PC\Documents\Python Scripts\Output.xlsx') as writer:
    IDNUMBERS.to_excel(writer, sheet_name='Foglio1')
    PSTARTING.to_excel(writer, sheet_name='Foglio2')
